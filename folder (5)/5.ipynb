# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-89788b63-9a98-4e63-b87d-66cf2c60486d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-89788b63-9a98-4e63-b87d-66cf2c60486d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Iris (2).csv to Iris (2).csv

# %%
import pandas as pd
df = pd.read_csv("Iris (2).csv")
df
# Out:
#       Id  SepalLengthCm  ...  PetalWidthCm         Species
# 0      1            5.1  ...           0.2     Iris-setosa
# 1      2            4.9  ...           0.2     Iris-setosa
# 2      3            4.7  ...           0.2     Iris-setosa
# 3      4            4.6  ...           0.2     Iris-setosa
# 4      5            5.0  ...           0.2     Iris-setosa
# ..   ...            ...  ...           ...             ...
# 145  146            6.7  ...           2.3  Iris-virginica
# 146  147            6.3  ...           1.9  Iris-virginica
# 147  148            6.5  ...           2.0  Iris-virginica
# 148  149            6.2  ...           2.3  Iris-virginica
# 149  150            5.9  ...           1.8  Iris-virginica
#
# [150 rows x 6 columns]

# %%
df["Species"].value_counts()
# Out:
# Iris-virginica     50
# Iris-versicolor    50
# Iris-setosa        50
# Name: Species, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df.plot(kind='scatter', x='SepalLengthCm',y='SepalWidthCm')

# %%
df.plot(kind='scatter', x='PetalLengthCm',y='PetalWidthCm')

# %%
import seaborn as sns
sns.jointplot( x='PetalLengthCm',y='PetalWidthCm',data=df)

# %%
sns.jointplot( x='PetalLengthCm',y='PetalWidthCm',data=df,hue="Species")

# %%
import matplotlib.pyplot as plt

sns.FacetGrid(df,hue='Species', height=8).map(plt.scatter,'PetalLengthCm','PetalWidthCm').add_legend()

# %%
sns.boxplot(y='PetalLengthCm',data=df)

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.boxplot(x='Species',y='PetalLengthCm',data=df)

# %%
sns.FacetGrid(df,hue='Species', height=8).map(sns.kdeplot,'PetalLengthCm','PetalWidthCm').add_legend()

# %%
sns.FacetGrid(df,hue='Species', height=8).map(sns.kdeplot,'PetalLengthCm').add_legend()

# %%
sns.pairplot(df.drop('Id',axis=1),hue='Species',height=4)
